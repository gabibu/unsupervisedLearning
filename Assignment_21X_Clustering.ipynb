# %% [markdown]
# # Assignment: Unsupervised Machine Learning \ Clustering

# %% [markdown]
# ## Part 1: Partitional Clustering

# %% [markdown]
# In this assignment you will experience with partitional, mixture model and hierarchical clustering. The analyses are made on real datasets under the circumstances of real life challenges in unsupervised machine learning.

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import squareform
from scipy.cluster import hierarchy
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %% [markdown]
# ### Read blood test results as an EMR from an Excel file

# %%
# Open the file
xlsx = pd.ExcelFile("EMR-Blood.xlsx")

# Get the first sheet as an object
sheet1 = xlsx.parse(0)

# Set the Key column as the index
sheet1.set_index("Key", inplace=True)

# Show first 10 rows
sheet1[:10]
# Out:
#       Na     K    ALT    AST    WBC   RBC   Hgb   Hct
# Key
# 1    141  4.65  26.33  26.09  10.25  4.06  17.6  36.3
# 2    140  4.96  20.67  26.46   6.13  3.80  13.2  35.6
# 3    136  3.66  15.72  19.95   5.86  4.26  16.2  43.7
# 4    136  4.74  17.16  24.39  10.80  4.83  16.1  49.8
# 5    140  4.74  17.12  22.90   6.59  4.05  12.6  39.1
# 6    146  3.98  24.43  22.87   4.53  4.04  17.9  47.3
# 7    144  5.29  15.98  18.14  10.12  3.96  17.2  47.9
# 8    138  4.57  17.44  21.88   4.66  4.91  13.7  41.5
# 9    144  3.96  21.43  28.54   4.57  4.72  15.1  47.6
# 10   147  3.99  21.46  29.10   4.41  4.73  17.4  42.7

# %% [markdown]
# ### Blood Test Abbreviations
# - Na == Sodium
# - K == Potassium
# - ALT == Alanine transaminase
# - AST == Aspartate transaminase
# - WBC == White blood cells
# - RBC == Red blood cells
# - Hgb == Hemoglobin
# - Hct == Hematocrit

# %% [markdown]
# ### Use K-Means to create clusters according to variables of uniform distribution

# %%
# Retrieve the K, WBC and Hgb column values as the dataset to cluster
variables1 = ["K","WBC","Hgb"]
EMR3d1 = sheet1.loc[:, variables1].values

# Run the K-Means algorithm, assuming the correct number of clusters is 5
y_pred_KMeans1 = KMeans(n_clusters=5).fit_predict(EMR3d1)

# %% [markdown]
# ### Make a 3D chart

# %%
def make_chart (chart_data, y_pred, labels):
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.set_xlabel(labels[0])
    ax.set_ylabel(labels[1])
    ax.set_zlabel(labels[2])
    ax.scatter(chart_data[:,0], chart_data[:,1], chart_data[:,2], c=y_pred)

make_chart(EMR3d1, y_pred_KMeans1, variables1)

# %% [markdown]
# ## Challenge 211
#
# Humans can clearly spot 3 clusters, however, for machines it's much harder to "learn" that. In the above implementation, K-Means was given the value of 5 as K.
# Your mission, should you choose to accept it, is to develop a **generic** mechanism for finding the most reasonable number of clusters by:
# 1. Iterating K over a reasonable range, which should be derived from the number of points
# 2. Harnessing one of the segmentation algorithms we learned as a heuristic to choose K
# 3. Showing the final clusters in a 3D chart

# %%
EMR3d1.shape
# Out:
# (100, 3)

# %%
# Add your code for Challenge 211 after this line, and keep it in this cell.

Sum_of_squared_distances = []
K = range(1,99)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(EMR3d1)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ## Part 2: Mixture Models Clustering

# %% [markdown]
# ### Use K-Means to create clusters according to variables of both uniform and Gaussian distributions

# %%
# Retrieve the ALT, AST and RBC column values as the dataset to cluster
variables2 = ["ALT","AST","RBC"]
EMR3d2 = sheet1.loc[:, variables2].values

# Run the K-Means algorithm, assuming the correct number of clusters is 2
y_pred_KMeans2 = KMeans(n_clusters=2).fit_predict(EMR3d1)

# Make a 3D chart
make_chart(EMR3d2, y_pred_KMeans2, variables2)

# %% [markdown]
# ## Challenge 212
# Scientists have found that in this population of patients, RBC distribution is uniform, AST distribution is a Gaussian and ALT distribution is a mixture of two Gaussians. Clearly, even by giving K-Means the correct K, the algorithm got to the wrong conclusion. This separation is "technically" correct, but lacks some underlying understanding of the natural phenomena. Your mission, should you choose to accept it, is to:
# 1. Apply the GMM algorithm on this data
# 2. Make any required (but reasonable) adjustments in order to find the true clusters
# 3. Show the final clusters in a 3D chart

# %%
# Add your code for Challenge 212 after this line, and keep it in this cell.
from sklearn.mixture import GaussianMixture
y_pred_KMeans2 = GaussianMixture(n_components=5).fit(EMR3d2).predict(EMR3d2)

make_chart(EMR3d2, y_pred_KMeans2, variables2)

# %% [markdown]
# ## Part 3: Hierarchical Clustering
# (Practice material by Etam Benger)

# %% [markdown]
# ### Different ways to calculate the distance between clusters can yield strikingly different results

# %%
# Labels
l = ['A', 'B', 'C', 'D', 'E', 'F']

# Distance matrix
# (Note that it must be symmetrical and its diagonal is always 0)
d = np.array([[0, 1, 3, 3, 3, 4],
              [1, 0, 4, 2, 3, 2],
              [3, 4, 0, 3, 2, 5],
              [3, 2, 3, 0, 2, 4],
              [3, 3, 2, 2, 0, 5],
              [4, 2, 5, 4, 5, 0]])

# %%
# The hierarchy.linkage function uses a condensed distance matrix,
# which is a flattened vector of the upper right triangle of the matrix:
# (Caution! If you use the distance matrix as is, you will get erroneous
# results -- in that case the algorithm will assume that each row is a
# vector that represents the respective point, and will calculate the
# euclidean distance between those vectors, which is absolute nonsense.)
squareform(d)
# Out:
# array([1, 3, 3, 3, 4, 4, 2, 3, 2, 3, 2, 5, 2, 4, 5])

# %%
# Please read the documentation here:
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html
#
# As you'll see below, the different methods of linkage may produce very different structures
# and, consequently, very different clusters. Try to understand why (look at the distance matrix
# and follow the formulas in the documentation).
# Sometimes the characteristics of the problem suggest what method is more natural to use than
# the others. This is especially true with respect to the complete (= farthest point) and single
# (= nearest point) methods. Other times the 'correct' method to use is not obvious at all, and
# it requires inspecting the results and the data thoroughly. The average method usually works
# well, however.

methods = ['single', 'complete', 'average', 'ward']  # There are other methods as well, see documentation

plt.figure(figsize=(10, 5))

for i, method in enumerate(methods):
    plt.subplot(2, 2, i+1)
    plt.title(method)
    
    ############# This is the relevant part: #############
    #                                                    #
    lnk = hierarchy.linkage(squareform(d), method)
    hierarchy.dendrogram(lnk, labels=l, color_threshold=0)
    #                                                    #
    ######################################################
    
    plt.ylim(0, 5.5)
    plt.grid(axis='y')

plt.tight_layout()

# %% [markdown]
# ### Altering the order in which clusters are joined can also yield strikingly different results

# %%
# Labels
l = ['A', 'B', 'C', 'D', 'E']

# Distance matrices
epsilon = 10**-16
a, b = 1 + epsilon, 1 - epsilon

d1 = np.array([[0, 1, a, 5, 5],
               [1, 0, 3, 5, 5],
               [a, 3, 0, 3, b],
               [5, 5, 3, 0, 1],
               [5, 5, b, 1, 0]])

d2 = np.array([[0, 1, b, 5, 5],
               [1, 0, 3, 5, 5],
               [b, 3, 0, 3, a],
               [5, 5, 3, 0, 1],
               [5, 5, a, 1, 0]])

# %%
# The Frobenius distance between the matrices is negligible
np.sqrt(np.sum((d1-d2)**2))
# Out:
# 2.2204460492503131e-16

# %%
# But the resulting clusters are very different!

plt.figure(figsize=(10, 3))

for i, d in enumerate([d1, d2]):
    plt.subplot(1, 2, i+1)
    plt.title('d%s' % (i+1,))

    lnk = hierarchy.linkage(squareform(d), 'complete') # You can experiment with the different methods ('single', 'complete', 'average', 'ward')
    hierarchy.dendrogram(lnk, labels=l, color_threshold=0)

    plt.ylim(0, 6)
    plt.grid(axis='y')

plt.tight_layout()

# %% [markdown]
# ## Challenge 213
# Data preparation and preprocessing can help in reducing such "hypersensitivity". One of the techniques is to clean the distance matrix from noise before the actual clustering. This can be done by... clustering. Your mission, should you choose to accept it, is to:
# 1. Apply the K-Means algorithm to clean the distance matrix, assuming the correct number of clusters is 4. Clustering can be made on each matrix independently, although in some cases it's wiser to do a cross-matrix clustering.
# 2. Create new cleaned versions of the distance matrices (d1_clean and d2_clean)
# 3. Repeat the above process

# %%
# Add your code for Challenge 213 after this line, and keep it in this cell.
d1_clusters = KMeans(n_clusters=4, random_state=9999).fit_predict(d1)
d2_clusters = KMeans(n_clusters=4, random_state=9999).fit_predict(d2)
(d1_clusters, d2_clusters)
# Out:
# (array([3, 0, 2, 1, 1], dtype=int32), array([3, 0, 2, 1, 1], dtype=int32))

# %%
def clean(distance_matrix):
    cleaned = np.zeros(shape=distance_matrix.shape)
    clusters = KMeans(n_clusters=4, random_state=9999).fit_predict(distance_matrix)
    for i in range(0, distance_matrix.shape[0]):
        i_cluster = clusters[i]
        for j in range(0, distance_matrix.shape[1]):
            j_cluster = clusters[j]
        
            distance = abs(i_cluster - j_cluster)
        
            cleaned[i][j] = distance 
        
    return cleaned

d1_clean = clean(d1)
d2_clean =clean(d2)

(d1_clean, d2_clean)
# Out:
# (array([[ 0.,  3.,  1.,  2.,  2.],
#         [ 3.,  0.,  2.,  1.,  1.],
#         [ 1.,  2.,  0.,  1.,  1.],
#         [ 2.,  1.,  1.,  0.,  0.],
#         [ 2.,  1.,  1.,  0.,  0.]]), array([[ 0.,  3.,  1.,  2.,  2.],
#         [ 3.,  0.,  2.,  1.,  1.],
#         [ 1.,  2.,  0.,  1.,  1.],
#         [ 2.,  1.,  1.,  0.,  0.],
#         [ 2.,  1.,  1.,  0.,  0.]]))

# %% [markdown]
# ### Analyzing voting data

# %%
df = pd.read_csv('Elections.csv')
df.sample(10)
# Out:
#       TownNumber    TownName  Potential  TotalVotes  PercentVote  Qualified  \
# 797          730      אליפלט        374         229        61.23        227
# 657          594       צפריה        344         283        82.27        281
# 186          944  בסמת טבעון       3908        1284        32.86       1240
# 897         1207        לבון        247         183        74.09        179
# 110          507   כפר יאסיף       6137        4115        67.05       4053
# 226         3788       טלמון        887         824        92.90        822
# 321          571  בית גמליאל        662         512        77.34        507
# 529          800   בית חנניה        450         346        76.89        344
# 1088        3556       אלמוג        118          94        79.66         92
# 992         1175        עידן        266         149        56.02        148
#
#       Disqualified  Avoda  Or  BaitYehudi  ...   Brit  Gever  Zomet  Zabar  \
# 797              2     13   0           5  ...      0      0      0      0
# 657              2      6   0          83  ...      0      0      0      0
# 186             44     63   0          21  ...      5      2      0      3
# 897              4     38   0           0  ...      1      0      0      0
# 110             62     45   0           2  ...      0      0      4      0
# 226              2      0   0         150  ...      0      0      0      0
# 321              5     14   0         178  ...      0      0      0      0
# 529              2     66   0           8  ...      0      0      0      1
# 1088             2     38   0           1  ...      0      0      0      0
# 992              1     36   0           0  ...      0      0      0      0
#
#       Daam  AleYarok  Koah.2  Lidar  Yarok  Shas
# 797      0         1       0      0      0    42
# 657      0         1       0      0      1    11
# 186      6         1       2      5      3    12
# 897      0         1       0      0      1     1
# 110      3         1       0      1      2     1
# 226      0         1       0      0      0    21
# 321      0         0       0      0      4    36
# 529      1         3       0      0      3     2
# 1088     0         1       0      0      0     0
# 992      0         0       0      0      0     3
#
# [10 rows x 41 columns]

# %%
df.TownName[i]
# Out:
# 'ירושלים'

# %%
# Number of cities to cluster (they are ordered by the total number of votes, descending)
n = 100

# Data matrix and labels list
x = np.zeros((n, 34))
labels_r = []

# Iterate over rows in dataframe
for i, row in df[:n].iterrows():
    x[i] = row[7:]                         # take only the votes, not the other meta-data
    labels_r.append(df.TownName[i][::-1])  # reverse the labels (because they are in Hebrew)

# Normalize rows (so they represent proportions):
x = x/(np.sum(x, axis=1).reshape(-1, 1))

# %%
# You can experiment with the different methods ('single', 'complete', 'average', 'ward'):
# (Note that we don't use squareform here, so the linkage function will assume by
# default that x is not a distance matrix but a set of observations, and will calculate
# the euclidean distance between them. We could, instead, calculate our own distance
# matrix using other distance measures between distributions, for example the Kullback-
# Leibler divergence (relative entropy).)
lnk = hierarchy.linkage(x, 'average')

# %%
plt.figure(figsize=(20, 5))

# You can experiment with the color threshold to observe the different possible clusterizations:
hierarchy.dendrogram(lnk, labels=labels_r, leaf_font_size=14, color_threshold=0.5);

# %% [markdown]
# ## Challenge 214
# When using our domain expertise regarding the population in Israeli cities and villages, we can cleary conclude from the results that the main "tribes" in our society are Jews and Arabs, where Jews are split according to their religiosity. Although the jingle says "there's no more right or left", your mission, should you choose to accept it, is to find a way to distinguish between right and left.

# %%
import xml.etree.ElementTree as ET

tree = ET.parse('yeshuvim_20190301.xml')
root = tree.getroot()

# %%
napas = [int(elem.text.strip()) for elem in root.iter() if elem.tag == 'סמל_נפה']
yeshuvs = [elem.text.strip() for elem in root.iter() if elem.tag == 'שם_ישוב']

yeshuvs_napa = {}
for yeshuv, napa in zip(yeshuvs, napas):
    yeshuvs_napa[yeshuv] = napa

# %%
df['napa'] = df.TownName.apply(lambda x: yeshuvs_napa[x] if x in yeshuvs_napa else None)
df.sample(10)
# Out:
#       TownNumber     TownName  Potential  TotalVotes  PercentVote  Qualified  \
# 596          408   נאות מרדכי        459         314        68.41        314
# 857         3599        מחולה        262         200        76.34        199
# 328          739   שדה עוזיהו        752         501        66.62        497
# 824          748        מסלול        308         212        68.83        211
# 1034        3784         שמעה        206         131        63.59        131
# 14          6400       הרצליה      74585       48046        64.42      47558
# 775          364    כפר אוריה        317         238        75.08        236
# 656          792  נתיב השיירה        384         283        73.70        280
# 1092        1177        טללים        142          93        65.49         93
# 205         1310         לפיד       1342        1054        78.54       1047
#
#       Disqualified  Avoda  Or  BaitYehudi  ...   Gever  Zomet  Zabar  Daam  \
# 596              0    128   0           0  ...       1      0      0     0
# 857              1      1   0          77  ...       0      0      0     0
# 328              4     29   0          20  ...       0      0      0     1
# 824              1     50   0           1  ...       0      0      0     0
# 1034             0      5   0           0  ...       0      0      0     0
# 14             488   7341  18         903  ...      10     10     51    30
# 775              2     46   0           1  ...       0      0      1     0
# 656              3    111   1           4  ...       0      0      0     0
# 1092             0      9   0          15  ...       0      0      0     4
# 205              7    168   0          17  ...       1      1      1     1
#
#       AleYarok  Koah.2  Lidar  Yarok  Shas  napa
# 596          3       0      0      1     2  21.0
# 857          0       0      0      1    11  75.0
# 328          0       0      0      0   104  61.0
# 824          1       0      0      0    20  62.0
# 1034         0       0      0      0    12  77.0
# 14         219      10     10    255  2170  51.0
# 775          1       0      0      4    10  11.0
# 656          1       1      0      1    13  24.0
# 1092         0       0      0      0     5  62.0
# 205          7       0      0      2    19  43.0
#
# [10 rows x 42 columns]

# %%
yeshuvs_napa
# Out:
# {'רותם': 75,
#  'גבעת אלה': 23,
#  'ברקאי': 32,
#  'מבשרת ציון': 11,
#  'קרית שמונה': 21,
#  'מגן שאול': 23,
#  'תירוש': 11,
#  'נווה אור': 23,
#  'אביגדור': 61,
#  'בית הלוי': 41,
#  'מעגן מיכאל': 32,
#  'גורן': 24,
#  'שעורים': 22,
#  'שפר': 21,
#  'אשרת': 24,
#  'יד השמונה': 11,
#  'גבים': 61,
#  'פוריה עילית': 22,
#  'רמות נפתלי': 21,
#  'רחובות': 44,
#  'שבי דרום': 62,
#  'נווה מיכאל': 11,
#  'שומרה': 24,
#  'מחנה תל נוף': 44,
#  'עין איילה': 32,
#  'שער אפרים': 41,
#  'מחסיה': 11,
#  'כדורי': 22,
#  'עראמשה': 24,
#  'טירת כרמל': 31,
#  'טובא-זנגריה': 21,
#  'אבטין': 31,
#  'כפר האורנים': 74,
#  'שכניה': 24,
#  'כנרת )מושבה(': 22,
#  'מנות': 24,
#  'ביתר עילית': 76,
#  'נווה מבטח': 61,
#  'ניר עקיבא': 62,
#  'שדה ורבורג': 42,
#  'רועי': 75,
#  'רנן': 62,
#  'צור נתן': 42,
#  'עין גדי': 62,
#  'יערה': 24,
#  'תרום': 11,
#  'אומץ': 41,
#  'כפר סבא': 42,
#  'גמזו': 43,
#  'גדות': 21,
#  'אבנת': 75,
#  'משמר דוד': 43,
#  'לפידות': 24,
#  'זוהר': 61,
#  'כחל': 21,
#  'זרזיר': 23,
#  'צוחר': 62,
#  'תלמי יחיאל': 61,
#  'שוהם': 43,
#  'ניל"י': 74,
#  'הגושרים': 21,
#  'כרם בן זמרה': 21,
#  'בניה': 44,
#  'כוכב השחר': 74,
#  'ירושלים': 11,
#  'רשפים': 23,
#  'רמות מאיר': 43,
#  'איתמר': 72,
#  'כרמיה': 61,
#  'חצרות יסף': 24,
#  'אלקנה': 73,
#  'עופר': 32,
#  'בית הלל': 21,
#  'מעלה אדומים': 76,
#  'גלעד )אבן יצחק(': 23,
#  'אבו עמאר )שבט(': 62,
#  'אליקים': 23,
#  'גינוסר': 22,
#  'נחשולים': 32,
#  'קלע': 29,
#  'דייר חנא': 24,
#  'בית אלפא': 23,
#  'רמת מגשימים': 29,
#  'גדעונה': 23,
#  'אחוזת ברק': 23,
#  'בני ברק': 52,
#  'דור': 32,
#  "ח'ואלד )שבט(": 25,
#  'משמר הנגב': 62,
#  'גבולות': 62,
#  'חרוצים': 41,
#  'כפר זיתים': 22,
#  'כפר עציון': 76,
#  'פורת': 41,
#  'באר יעקב': 43,
#  'שלומי': 24,
#  'תושיה': 62,
#  'העוגן': 41,
#  'חצר בארותיים': 41,
#  'שדה משה': 61,
#  'גבעת שמש': 11,
#  'גבעת אבני': 22,
#  'שפרעם': 24,
#  'טמרה': 24,
#  'גת )קיבוץ(': 61,
#  'נווה זוהר': 62,
#  'עין חצבה': 62,
#  'עין החורש': 41,
#  'סעוה': 62,
#  'רמת השרון': 51,
#  'נתיב הל"ה': 11,
#  'גבעת ניל"י': 32,
#  "סאג'ור": 24,
#  'רביבים': 62,
#  'שלווה': 61,
#  'שלוחות': 23,
#  'חלץ': 61,
#  'מעונה': 24,
#  'סייד )שבט(': 62,
#  'בית הגדי': 62,
#  'גליל ים': 51,
#  'לבון': 24,
#  'נאות סמדר': 62,
#  'ערב אל נעים': 24,
#  'נתיב השיירה': 24,
#  'טמרה )יזרעאל(': 23,
#  'מכחול': 62,
#  'זיתן': 43,
#  'אום אל-פחם': 32,
#  'גרופית': 62,
#  'זנוח': 11,
#  'בני עטרות': 42,
#  'ניר ישראל': 61,
#  'אשלים': 62,
#  'בני דרום': 44,
#  'נווה ירק': 42,
#  'אכסאל': 23,
#  'שדות ים': 32,
#  'פדויים': 62,
#  'חגור': 42,
#  'גבעת חיים )מאוחד(': 41,
#  'מתתיהו': 74,
#  'סואעד )כמאנה( )שבט(': 24,
#  'חצרים': 62,
#  'כסרא-סמיע': 24,
#  'קרית אונו': 52,
#  'עין השופט': 23,
#  'גני טל': 44,
#  'חיבת ציון': 41,
#  'געש': 41,
#  'אופקים': 62,
#  'כרם בן שמן': 43,
#  'שומריה': 62,
#  'קרית ארבע': 77,
#  'שריגים )לי-און(': 11,
#  'בית מאיר': 11,
#  'משמר השבעה': 43,
#  'עין המפרץ': 24,
#  'חדיד': 43,
#  'מרחב עם': 62,
#  'ניר עוז': 62,
#  'אל-עזי': 61,
#  'גבעת שמואל': 42,
#  'רומת הייב': 25,
#  'אייל': 42,
#  'אבן יהודה': 41,
#  'שדה אליעזר': 21,
#  'איבים': 61,
#  'לוזית': 11,
#  'אעבלין': 24,
#  'יובל': 21,
#  'ברור חיל': 61,
#  'צופית': 42,
#  'כפר סירקין': 42,
#  'תקוע': 76,
#  'פתחיה': 43,
#  "ח'ואלד": 31,
#  'שדה עוזיהו': 61,
#  'משמר הירדן': 21,
#  'ירדנה': 23,
#  'עזריאל': 41,
#  'נחשון': 11,
#  'גיתה': 24,
#  'מורשת': 24,
#  'היוגב': 23,
#  'בית דגן': 43,
#  'מסדה': 22,
#  'מגידו': 23,
#  'נוקדים': 76,
#  'תלמי ביל"ו': 62,
#  'גבע בנימין': 74,
#  'עין חוד': 32,
#  'נשר': 31,
#  'פדיה': 43,
#  'שזור': 24,
#  'מחנה הילה': 44,
#  'בית צבי': 32,
#  'ירקונה': 42,
#  'אבו גוש': 11,
#  'גילון': 24,
#  'בן שמן )כפר נוער(': 43,
#  'כפר כנא': 25,
#  'ערוגות': 61,
#  "ביר הדאג'": 62,
#  'ריינה': 25,
#  'חריש': 32,
#  'מטע': 11,
#  'ביתן אהרן': 41,
#  'עיינות': 44,
#  'שלומית': 62,
#  'חבצלת השרון': 41,
#  'מסילת ציון': 11,
#  'פעמי תש"ז': 62,
#  'באקה אל-גרביה': 32,
#  'נוף איילון': 43,
#  'אשבול': 62,
#  'ענב': 73,
#  'רמת רזיאל': 11,
#  'שמשית': 23,
#  'סולם': 23,
#  'כפר יונה': 41,
#  'מיטב': 23,
#  'חמדת': 75,
#  'תומר': 75,
#  "כפר חסידים א'": 31,
#  'אפרת': 76,
#  'בית שאן': 23,
#  'גן שורק': 44,
#  'אשכולות': 77,
#  'עמינדב': 11,
#  'נתניה': 41,
#  'חגי': 77,
#  'אבו קרינאת )יישוב(': 62,
#  'צור הדסה': 11,
#  'כפר דניאל': 43,
#  'מחנה מרים': 61,
#  'כפר גלעדי': 21,
#  'אחיסמך': 43,
#  'מצדות יהודה': 77,
#  'רגבים': 32,
#  'נורדיה': 41,
#  'המעפיל': 41,
#  'מגאר': 22,
#  'הר אדר': 74,
#  "יאנוח-ג'ת": 24,
#  'הוזייל )שבט(': 62,
#  'אזור': 53,
#  'קרית שלמה': 41,
#  'בת חפר': 41,
#  'מנוחה': 61,
#  'סמר': 62,
#  'בית חנן': 44,
#  'מרחביה )מושב(': 23,
#  'הר עמשא': 62,
#  'מטולה': 21,
#  'סלעית': 73,
#  'ניצני סיני': 62,
#  'צבעון': 21,
#  'דייר ראפאת': 11,
#  'שיבולים': 62,
#  'רגבה': 24,
#  'בית השיטה': 23,
#  'כפר תפוח': 73,
#  'שדה יעקב': 23,
#  'עזוז': 62,
#  'נירן': 75,
#  'כפר ביאליק': 31,
#  'דברת': 23,
#  'כוכב מיכאל': 61,
#  'הודיות': 22,
#  'פתח תקווה': 42,
#  'פסוטה': 24,
#  'כפר הנגיד': 44,
#  'סאסא': 21,
#  'נוגה': 61,
#  'כפר הנשיא': 21,
#  'חפצי-בה': 23,
#  'כפר בלום': 21,
#  'חירות': 41,
#  'לפיד': 43,
#  'מלכישוע': 23,
#  'נווה אילן': 11,
#  'מעלה שומרון': 73,
#  'גיניגר': 23,
#  'נצר סרני': 43,
#  'קודייראת א-צאנע)שבט(': 62,
#  'אבירים': 24,
#  'עין הנצי"ב': 23,
#  "אבו ג'ווייעד )שבט(": 62,
#  'צלפון': 11,
#  'רווחה': 61,
#  'בית קשת': 22,
#  'רמות': 29,
#  'שורשים': 24,
#  'דקל': 62,
#  'בני דקלים': 61,
#  'אודים': 41,
#  'לכיש': 61,
#  'יטבתה': 62,
#  'מנרה': 21,
#  'קדמה': 61,
#  'ראמה': 24,
#  'נתיבות': 62,
#  'ראש צורים': 76,
#  'צופים': 73,
#  'עין צורים': 61,
#  'יקום': 41,
#  'מעלה מכמש': 74,
#  'עשרת': 44,
#  'עזריקם': 61,
#  'צור משה': 41,
#  'תלם': 77,
#  'יחיעם': 24,
#  'מבקיעים': 61,
#  'מאור': 32,
#  'שבי שומרון': 72,
#  'כפר זוהרים': 11,
#  'בית עובד': 44,
#  'הוואשלה )שבט(': 62,
#  'רבבה': 72,
#  'גבעתיים': 52,
#  'חזון': 22,
#  'כפר מצר': 25,
#  'שדה נחמיה': 21,
#  'יעד': 24,
#  'מולדת': 23,
#  'ניר משה': 62,
#  'עין עירון': 32,
#  'מעש': 42,
#  'שפיים': 41,
#  'יודפת': 24,
#  'הודיה': 61,
#  'בארי': 62,
#  'בר יוחאי': 21,
#  'בית חשמונאי': 43,
#  'איתנים': 11,
#  'מייסר': 32,
#  'כנרת )קבוצה(': 22,
#  'ריחן': 71,
#  'נווה זיו': 24,
#  'עמיר': 21,
#  'גבעת יואב': 29,
#  'בית רבן': 44,
#  'משואה': 75,
#  'עין שמר': 32,
#  'עראבה': 24,
#  'זבארגה )שבט(': 62,
#  'צרופה': 32,
#  'ירחיב': 42,
#  'משואות יצחק': 61,
#  'שובל': 62,
#  'ראש העין': 42,
#  'דפנה': 21,
#  'רקפת': 24,
#  'כפר אביב': 44,
#  'צוריאל': 24,
#  "דריג'את": 62,
#  'שמרת': 24,
#  'קציר': 32,
#  'קדר': 76,
#  'תלמי יפה': 61,
#  'ניצן': 61,
#  'עינת': 42,
#  "כעביה-טבאש-חג'אג'רה": 25,
#  'תקומה': 62,
#  'גבעת עוז': 23,
#  'כפר קאסם': 42,
#  'לימן': 24,
#  'גאליה': 44,
#  'כדיתה': 21,
#  'שעב': 24,
#  'בארות יצחק': 42,
#  'מגדל העמק': 23,
#  'משען': 61,
#  'דאלית אל-כרמל': 31,
#  'כפר עבודה': 41,
#  'אביעזר': 11,
#  'בן שמן )מושב(': 43,
#  'מזור': 42,
#  'מזכרת בתיה': 44,
#  'בחן': 41,
#  "ג'דיידה-מכר": 24,
#  'אבו רוקייק )שבט(': 62,
#  'אליאב': 61,
#  'אילת': 62,
#  'הסוללים': 23,
#  'שדי תרומות': 23,
#  'מחנה יוכבד': 62,
#  'מרגליות': 21,
#  'עין נקובא': 11,
#  'שדה יצחק': 32,
#  'יכיני': 61,
#  'נעורים': 41,
#  'גזר': 43,
#  'מנשית זבדה': 25,
#  'עמיקם': 32,
#  'עלמה': 21,
#  'גן שמואל': 32,
#  'בורגתה': 41,
#  'חגלה': 41,
#  'גילת': 62,
#  'ראשון לציון': 44,
#  "ע'ג'ר": 29,
#  'אדמית': 24,
#  'ברקן': 73,
#  'ניר גלים': 44,
#  'כמון': 24,
#  'דורות': 61,
#  'יתיר': 62,
#  'חדרה': 32,
#  'מגדל עוז': 76,
#  'צורית': 24,
#  'סער': 24,
#  'בת שלמה': 32,
#  'עמיעד': 21,
#  'אילניה': 22,
#  'בני ראם': 44,
#  'נטור': 29,
#  'מישר': 44,
#  'שדה אילן': 22,
#  'כרם שלום': 62,
#  'מחניים': 21,
#  'קרית יערים': 11,
#  'רוויה': 23,
#  'ביר אל-מכסור': 24,
#  'בית יוסף': 23,
#  'מלאה': 23,
#  'גבעת יערים': 11,
#  'בטחה': 62,
#  'נירים': 62,
#  'מחולה': 75,
#  'כפר רופין': 23,
#  'יסוד המעלה': 21,
#  'יציץ': 43,
#  'כפר חרוב': 29,
#  'משכיות': 75,
#  'ירכא': 24,
#  'כפר גדעון': 23,
#  'פלך': 24,
#  'בית נחמיה': 43,
#  'כפר ויתקין': 41,
#  'בני נצרים': 62,
#  'כרכום': 22,
#  'נאות מרדכי': 21,
#  'כפר המכבי': 31,
#  'כפר טרומן': 43,
#  'מחנה יתיר': 62,
#  'מקווה ישראל': 53,
#  'כפר מסריק': 24,
#  'אור יהודה': 52,
#  'מגן': 62,
#  'יהל': 62,
#  'שגב-שלום': 62,
#  'עין השלושה': 62,
#  'שדמות דבורה': 22,
#  'אום אל-קוטוף': 32,
#  'אטרש )שבט(': 62,
#  'יגל': 43,
#  'גן השומרון': 32,
#  'חצרות חולדה': 43,
#  'מבוא דותן': 71,
#  'חצור-אשדוד': 61,
#  'ינון': 61,
#  'מצליח': 43,
#  'רמלה': 43,
#  'אשתאול': 11,
#  'אליכין': 41,
#  'צנדלה': 23,
#  'עוזייר': 25,
#  'בית גוברין': 61,
#  'סנסנה': 77,
#  'קשת': 29,
#  'כפר קיש': 22,
#  'גבעולים': 62,
#  'גיתית': 75,
#  'דן': 21,
#  'כפר קרע': 32,
#  'סוסיה': 77,
#  'קרית יערים)מוסד(': 11,
#  'גפן': 11,
#  'לוחמי הגיטאות': 24,
#  'שואבה': 11,
#  'תובל': 24,
#  'ראס אל-עין': 24,
#  'בת הדר': 61,
#  'תל תאומים': 23,
#  'שער העמקים': 31,
#  'שעלבים': 43,
#  'קדימה-צורן': 41,
#  'כפר יחזקאל': 23,
#  'כפר פינס': 32,
#  'קלנסווה': 41,
#  'כנף': 29,
#  'נעלה': 74,
#  'שושנת העמקים': 41,
#  'בסמת טבעון': 23,
#  'רינתיה': 42,
#  'עדנים': 42,
#  'נופך': 42,
#  'בלפוריה': 23,
#  'יד נתן': 61,
#  'אבו סנאן': 24,
#  'יונתן': 29,
#  'יקנעם עילית': 23,
#  'אירוס': 44,
#  'ביריה': 21,
#  'מסילות': 23,
#  'עין ראפה': 11,
#  'בני עי"ש': 44,
#  'דימונה': 62,
#  'כוכב יעקב': 74,
#  'תראבין א-צאנע)ישוב(': 62,
#  'זמר': 41,
#  'פלמחים': 44,
#  'ברוכין': 73,
#  'יצהר': 72,
#  'גדרה': 44,
#  'עדי': 24,
#  'רמת השופט': 23,
#  'רימונים': 74,
#  'אליפלט': 21,
#  'רם-און': 23,
#  'בוקעאתא': 29,
#  'צביה': 24,
#  'מלכיה': 21,
#  'חרשים': 24,
#  'בית חלקיה': 44,
#  'ניצנים': 61,
#  'בת ים': 53,
#  'בית רימון': 23,
#  'בית עזרא': 61,
#  'מענית': 32,
#  'כפר ורבורג': 61,
#  'מפלסים': 61,
#  'בר גיורא': 11,
#  'בית חירות': 41,
#  'להבות הבשן': 21,
#  'בני דרור': 41,
#  'בית אלעזרי': 44,
#  'בקעות': 75,
#  'באר גנים': 62,
#  'כחלה': 62,
#  'תנובות': 41,
#  'כרמי צור': 77,
#  'לביא': 22,
#  'אספר': 77,
#  'עלומים': 62,
#  'אחיטוב': 41,
#  'עבדון': 24,
#  'קורנית': 24,
#  'רחוב': 23,
#  'שניר': 21,
#  'דבורה': 23,
#  'כפר גליקסון': 32,
#  'אבו קורינאת )שבט(': 62,
#  'שלווה במדבר': 62,
#  'כפר סאלד': 21,
#  'יקיר': 73,
#  'זיקים': 61,
#  'אסד )שבט(': 62,
#  'משמרות': 32,
#  'אוהד': 62,
#  'חצב': 61,
#  'שריד': 23,
#  'ורדון': 61,
#  'כפר מימון': 62,
#  'בית גמליאל': 44,
#  'חמאם': 22,
#  'כפר סילבר': 61,
#  'עומר': 62,
#  'גבעת ישעיהו': 11,
#  'שמיר': 21,
#  'עגור': 11,
#  'מסלול': 62,
#  'ניצני עוז': 41,
#  'ראס עלי': 31,
#  "כאוכב אבו אל-היג'א": 24,
#  'מצפה שלם': 75,
#  'קרית ביאליק': 31,
#  'ניר צבי': 43,
#  'בית שערים': 23,
#  'מצפה רמון': 62,
#  "חוג'ייראת )ד'הרה(": 24,
#  'אביבים': 21,
#  'ספיר': 62,
#  'שילה': 74,
#  'עין כרמל': 32,
#  'אלישמע': 42,
#  'מגדלים': 72,
#  'תדהר': 62,
#  'נווה': 62,
#  'בית אורן': 32,
#  'אמציה': 61,
#  'שחר': 61,
#  "ג'לג'וליה": 42,
#  'כיסופים': 62,
#  'רכסים': 31,
#  'מאיר שפיה': 32,
#  'בית זיד': 23,
#  'תלמי אליהו': 62,
#  'כפר יהושע': 23,
#  'תעוז': 11,
#  'שקד': 71,
#  'תלמים': 61,
#  'יראון': 21,
#  'יד חנה': 41,
#  'משמרת': 41,
#  'כפר נטר': 41,
#  'חבר': 23,
#  'בצת': 24,
#  'כפר תבור': 22,
#  'אליפז': 62,
#  'הדר עם': 41,
#  'קרית נטפים': 73,
#  'דלתון': 21,
#  'קדמת צבי': 29,
#  'עמיחי': 74,
#  'יד רמב"ם': 43,
#  'חשמונאים': 74,
#  'כפר אחים': 61,
#  'אמירים': 21,
#  'ניר עציון': 32,
#  'אבן ספיר': 11,
#  'מכמורת': 41,
#  'חולתה': 21,
#  'קרית ענבים': 11,
#  'גבעת כ"ח': 42,
#  'חצבה': 62,
#  'גנות הדר': 41,
#  'פוריה - נווה עובד': 22,
#  'חורפיש': 24,
#  'נגבה': 61,
#  'גבת': 23,
#  'יסעור': 24,
#  'גבעת השלושה': 42,
#  'נצר חזני': 44,
#  'מעברות': 41,
#  'יסודות': 44,
#  'בית שמש': 11,
#  'עמנואל': 73,
#  'זכריה': 11,
#  'גדיש': 23,
#  'רמות מנשה': 23,
#  'שקף': 61,
#  'גנות': 43,
#  'אלומה': 61,
#  'טנא': 77,
#  'מדרשת רופין': 41,
#  'כפר רות': 43,
#  'אעצם )שבט(': 62,
#  'סתריה': 43,
#  'אורנים': 31,
#  'עידן': 62,
#  'ציפורי': 23,
#  'שער מנשה': 32,
#  'חלמיש': 74,
#  'נטף': 11,
#  'תלמי יוסף': 62,
#  'שפיר': 61,
#  'יבנה': 44,
#  'מיתר': 62,
#  'שדי חמד': 42,
#  'שובה': 62,
#  'יעף': 41,
#  'נחם': 11,
#  'אלוני אבא': 23,
#  'קליה': 75,
#  'רמת צבי': 23,
#  'תל אביב - יפו': 51,
#  'אפיק': 29,
#  'עמוקה': 21,
#  'הוד השרון': 42,
#  'צור יצחק': 42,
#  'נווה דניאל': 76,
#  'בית חורון': 74,
#  'כברי': 24,
#  'ניר עם': 61,
#  'רמות השבים': 42,
#  'זמרת': 62,
#  'פדואל': 73,
#  'ארסוף': 41,
#  'שיטים': 62,
#  'תלמי אלעזר': 32,
#  'חורה': 62,
#  "דגניה א'": 22,
#  'אלוני יצחק': 32,
#  'אפיקים': 22,
#  'נחל עוז': 61,
#  'שדה בוקר': 62,
#  'בית עוזיאל': 43,
#  'חמרה': 75,
#  'כרמיאל': 24,
#  'אלונים': 23,
#  'נווה ימין': 42,
#  'שדרות': 61,
#  'מבואות ים': 41,
#  "דגניה ב'": 22,
#  'גלאון': 61,
#  'מדרשת בן גוריון': 62,
#  'בית העמק': 24,
#  'באר שבע': 62,
#  'ניר אליהו': 42,
#  "ג'סר א-זרקא": 32,
#  'אור עקיבא': 32,
#  'עלי': 72,
#  'אמנון': 22,
#  'חולית': 62,
#  'נועם': 61,
#  'אדירים': 23,
#  'חיננית': 71,
#  'אורטל': 29,
#  'שדה נחום': 23,
#  'יבול': 62,
#  'ייט"ב': 75,
#  'קרית מלאכי': 61,
#  'טייבה )בעמק(': 23,
#  'אחווה': 61,
#  'בית יהושע': 41,
#  'מודיעין-מכבים-רעות': 43,
#  'תראבין א-צאנע )שבט(': 62,
#  'משמר השרון': 41,
#  'יובלים': 24,
#  'רעננה': 42,
#  'מעלה עירון': 32,
#  'רהט': 62,
#  'ראש פינה': 21,
#  'גברעם': 61,
#  'נווה שלום': 11,
#  'סלמה': 24,
#  'האון': 22,
#  'מעיליא': 24,
#  'גן שלמה': 44,
#  'עין הבשור': 62,
#  'כפר חנניה': 21,
#  'אלמוג': 75,
#  'תל קציר': 22,
#  'עין זיוון': 29,
#  'יקנעם )מושבה(': 23,
#  'שרשרת': 62,
#  'בית ינאי': 41,
#  'כפר החורש': 23,
#  'אודם': 29,
#  'קרית אתא': 31,
#  'אבן שמואל': 61,
#  'כפר חושן': 21,
#  'ניר יפה': 23,
#  'עתלית': 32,
#  'קדרון': 44,
#  'להבות חביבה': 32,
#  'גן יבנה': 44,
#  'שדה צבי': 62,
#  'כפר ראש הנקרה': 24,
#  'פרי גן': 62,
#  'טל שחר': 11,
#  'מחנה טלי': 62,
#  'נחף': 24,
#  'מרום גולן': 29,
#  'אבן מנחם': 24,
#  'בסמ"ה': 32,
#  'ניצנה )קהילת חינוך(': 62,
#  'שורש': 11,
#  'אדורה': 77,
#  'גיבתון': 44,
#  'צפת': 21,
#  'אלעד': 42,
#  'פארן': 62,
#  'ברכה': 72,
#  'כלנית': 22,
#  'ארגמן': 75,
#  'כפר שמואל': 43,
#  'לוד': 43,
#  'רתמים': 62,
#  'עיילבון': 22,
#  'גבעת זאב': 74,
#  'טורעאן': 25,
#  'גת רימון': 42,
#  'הילה': 24,
#  'מנחמיה': 22,
#  'משהד': 25,
#  'בן זכאי': 44,
#  'באר אורה': 62,
#  'מתת': 24,
#  'צופיה': 44,
#  'בית אל': 74,
#  'עולש': 41,
#  'יושיביה': 62,
#  'כרם יבנה )ישיבה(': 44,
#  "שייח' דנון": 24,
#  'כפר עזה': 61,
#  'משמר איילון': 43,
#  'מגדל': 22,
#  'עין מאהל': 25,
#  'זבדיאל': 61,
#  'נבטים': 62,
#  'נצאצרה )שבט(': 62,
#  'ניר יצחק': 62,
#  'איתן': 61,
#  'כפר הס': 41,
#  'ביצרון': 61,
#  'רוחמה': 61,
#  'בית זרע': 22,
#  'מעגלים': 62,
#  'ניר ח"ן': 61,
#  'נווה איתן': 23,
#  'מצפה נטופה': 23,
#  'כפר הרא"ה': 41,
#  'חניאל': 41,
#  'רוח מדבר': 62,
#  'צופר': 62,
#  'נמרוד': 29,
#  'שאר ישוב': 21,
#  'גבעת ברנר': 44,
#  'נופים': 73,
#  'אלקוש': 24,
#  'חספין': 29,
#  'חד-נס': 29,
#  'כאבול': 24,
#  'עופרה': 74,
#  'אילות': 62,
#  'נאות גולן': 29,
#  'שילת': 43,
#  'כנות': 61,
#  'הר גילה': 76,
#  'יגור': 31,
#  'סביון': 42,
#  'אבו תלול': 62,
#  'גורנות הגליל': 24,
#  'זרחיה': 61,
#  'מנוף': 24,
#  'שדמה': 44,
#  'נווה אבות': 32,
#  'עמקה': 24,
#  'עין אל-אסד': 24,
#  'אמונים': 61,
#  'רבדים': 61,
#  'מגל': 32,
#  'גינתון': 43,
#  'עין יעקב': 24,
#  'קלחים': 62,
#  'תמרת': 23,
#  'מעלה עמוס': 76,
#  'עכו': 24,
#  'גבעון החדשה': 74,
#  'כפר ידידיה': 41,
#  'דמיידה': 24,
#  'גן חיים': 42,
#  'מצפה אילן': 32,
#  'כפר מרדכי': 44,
#  "מג'דל שמס": 29,
#  'לוטם': 24,
#  'נטע': 61,
#  'פרזון': 23,
#  'אשדות יעקב  )מאוחד(': 22,
#  'רמת הכובש': 42,
#  'בצרה': 41,
#  'נגוהות': 77,
#  'כפר חיטים': 22,
#  'להבים': 62,
#  'ידידה': 11,
#  'עין תמר': 62,
#  'כפר חיים': 41,
#  'מיצר': 29,
#  'טירת יהודה': 42,
#  'בארותיים': 41,
#  'חברון': 77,
#  'אדרת': 11,
#  'שעל': 29,
#  'פרדס חנה-כרכור': 32,
#  'להב': 62,
#  'אורים': 62,
#  'נטועה': 24,
#  'אביטל': 23,
#  'גשר הזיו': 24,
#  'אלוני הבשן': 29,
#  "בית ג'ן": 24,
#  'זרועה': 62,
#  'חורשים': 42,
#  'שערי תקווה': 73,
#  'בקוע': 11,
#  'נווה ים': 32,
#  'טבריה': 22,
#  'ישע': 62,
#  'טפחות': 22,
#  'טייבה': 41,
#  'חלוץ': 24,
#  'ברעם': 21,
#  'דולב': 74,
#  'תאשור': 62,
#  'דחי': 23,
#  'עוקבי )בנו עוקבה(': 62,
#  'חוסנייה': 24,
#  'חמד': 43,
#  'אפיניש )שבט(': 62,
#  'משמר העמק': 23,
#  'שתולה': 24,
#  'בית שקמה': 61,
#  'דליה': 23,
#  'עין שריד': 41,
#  'עין הוד': 32,
#  'אחיעזר': 43,
#  'אלון הגליל': 23,
#  'רמת רחל': 11,
#  'קוממיות': 61,
#  'נחשונים': 42,
#  'כפר ברוך': 23,
#  'מעלות-תרשיחא': 24,
#  'אלמגור': 22,
#  'פני חבר': 77,
#  'פרוד': 21,
#  'אל-עריאן': 32,
#  'עיר אובות': 62,
#  'עצמון שגב': 24,
#  'מזרעה': 24,
#  "ג'ת": 32,
#  'כישור': 24,
#  'מגשימים': 42,
#  'כרמי קטיף': 61,
#  'אל סייד': 62,
#  'יפיע': 25,
#  'אור הגנוז': 21,
#  'ערד': 62,
#  "כפר חסידים ב'": 31,
#  'קבועה )שבט(': 62,
#  'מירב': 23,
#  'תל מונד': 41,
#  'נטעים': 44,
#  'נס ציונה': 44,
#  'מעלה החמישה': 11,
#  'צאלים': 62,
#  'מצפה אבי"ב': 24,
#  'צובה': 11,
#  'מכורה': 75,
#  'מצובה': 24,
#  'חוקוק': 22,
#  'טלמון': 74,
#  'דוב"ב': 21,
#  'כפר שמאי': 21,
#  'יהוד-מונוסון': 42,
#  'מצפה': 22,
#  'עלמון': 74,
#  'כליל': 24,
#  'מוצא עילית': 11,
#  "ג'נאביב )שבט(": 62,
#  'נצרת עילית': 25,
#  'כפר ביל"ו': 44,
#  'גן נר': 23,
#  'הזורע': 23,
#  'כפר מל"ל': 42,
#  'גני יוחנן': 44,
#  'שחרות': 62,
#  'מחנה יפה': 62,
#  'גשר': 22,
#  'מבוא ביתר': 11,
#  'פקיעין חדשה': 24,
#  'כסלון': 11,
#  'אלון שבות': 76,
#  'קרית טבעון': 31,
#  'עין חרוד )איחוד(': 23,
#  'מבועים': 62,
#  'גבעת חיים )איחוד(': 41,
#  'ירוחם': 62,
#  'אבני חפץ': 73,
#  'נהורה': 61,
#  'נהריה': 24,
#  'מדרך עוז': 23,
#  'דייר אל-אסד': 24,
#  'כפר מנחם': 61,
#  'קבוצת יבנה': 44,
#  'כפר ורדים': 24,
#  'נורית': 23,
#  'בית הערבה': 75,
#  "מג'ד אל-כרום": 24,
#  'טירה': 41,
#  'געתון': 24,
#  'אריאל': 73,
#  'דבירה': 62,
#  'אשקלון': 61,
#  'זכרון יעקב': 32,
#  'רעים': 62,
#  'כוכב יאיר': 42,
#  'חצור הגלילית': 21,
#  'שדה יואב': 61,
#  'באר מילכה': 62,
#  'אלפי מנשה': 73,
#  'עוזה': 61,
#  'מעלה לבונה': 74,
#  "בועיינה-נוג'ידאת": 25,
#  'מי עמי': 32,
#  'ארבל': 22,
#  "ניצן ב'": 61,
#  'אביחיל': 41,
#  'כפר מונש': 41,
#  'לוטן': 62,
#  "ג'ולס": 24,
#  'כרמים': 62,
#  'כפר יעבץ': 41,
#  'גבע כרמל': 32,
#  'אלעזר': 76,
#  'גשור': 29,
#  'ישעי': 11,
#  ...}

# %%
n = 100

x = np.zeros((n, 35))
labels_r = []

valid = 0
for i, row in df.iterrows():
    x[valid] = row[7:]                        
    
    town_name = df.TownName[i]
    
    if town_name not in yeshuvs_napa:
        continue
    
    
    x[valid][34] =  yeshuvs_napa[town_name]
    
    
    labels_r.append(df.TownName[i][::-1])  
    
    valid += 1 
    if valid == 100:
        break 
x = x/(np.sum(x, axis=1).reshape(-1, 1))

# %%
plt.figure(figsize=(20, 5))
hierarchy.dendrogram(lnk, labels=labels_r, leaf_font_size=14, color_threshold=0.5);

# %% [markdown]
# # Good Luck and Enjoy Learning Machine Learning!
